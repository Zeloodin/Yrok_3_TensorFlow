# %%
import keras
from keras.layers import *
import matplotlib.pyplot as plt
import numpy as np
import keras.utils
from tensorflow.keras.preprocessing import image

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train[:20]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5, 0, 9, 5, 5, 7, 9, 1, 0, 6, 4],
#       dtype=uint8)

# %%
for i in range(7):
    plt.subplot(4,7,i+1)
    plt.imshow(x_train[i])
plt.show()

# %%
input_shape = (28, 28, 1)

# %%
model_1 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      # Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      # MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(50,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_1.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
x_train = x_train / 255
x_test = x_test / 255
y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat = keras.utils.to_categorical(y_test, 10)

# %%
# %%time

history = model_1.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 25s 8ms/step - loss: 0.4256 - accuracy: 0.8516 - val_loss: 0.3343 - val_accuracy: 0.8827
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2897 - accuracy: 0.8969 - val_loss: 0.3086 - val_accuracy: 0.8884
# Epoch 3/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2506 - accuracy: 0.9093 - val_loss: 0.2876 - val_accuracy: 0.8949
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2221 - accuracy: 0.9190 - val_loss: 0.2649 - val_accuracy: 0.9060
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1997 - accuracy: 0.9278 - val_loss: 0.2698 - val_accuracy: 0.9089
# CPU times: user 43.4 s, sys: 4.48 s, total: 47.8 s
# Wall time: 1min

# %%
model_2 = keras.Sequential([
      keras.Input(shape=input_shape),
      Flatten(),
      Dense(50, activation = 'relu'),
      Dense(10, activation = 'softmax')
      ] )

# %%
model_2.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_2.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5243 - accuracy: 0.8173 - val_loss: 0.4578 - val_accuracy: 0.8391
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3987 - accuracy: 0.8580 - val_loss: 0.4494 - val_accuracy: 0.8383
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3614 - accuracy: 0.8704 - val_loss: 0.3991 - val_accuracy: 0.8572
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3353 - accuracy: 0.8783 - val_loss: 0.4039 - val_accuracy: 0.8545
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3182 - accuracy: 0.8846 - val_loss: 0.3875 - val_accuracy: 0.8600
# CPU times: user 32.8 s, sys: 4.02 s, total: 36.8 s
# Wall time: 32 s

# %%
model_3 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(50,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_3.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_3.fit(x_train, y_train_cat, batch_size=32, epochs=5,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.4223 - accuracy: 0.8482 - val_loss: 0.3251 - val_accuracy: 0.8851
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2791 - accuracy: 0.8995 - val_loss: 0.2747 - val_accuracy: 0.9011
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2354 - accuracy: 0.9141 - val_loss: 0.2733 - val_accuracy: 0.9017
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2041 - accuracy: 0.9246 - val_loss: 0.2824 - val_accuracy: 0.9037
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1805 - accuracy: 0.9333 - val_loss: 0.2686 - val_accuracy: 0.9020
# CPU times: user 43.8 s, sys: 4.22 s, total: 48 s
# Wall time: 1min 23s

# %%
model_4 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

# %%
model_4.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_4.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.4249 - accuracy: 0.8432 - val_loss: 0.3215 - val_accuracy: 0.8832
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2737 - accuracy: 0.8997 - val_loss: 0.2677 - val_accuracy: 0.9023
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2269 - accuracy: 0.9154 - val_loss: 0.2481 - val_accuracy: 0.9100
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1992 - accuracy: 0.9259 - val_loss: 0.2501 - val_accuracy: 0.9100
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1725 - accuracy: 0.9359 - val_loss: 0.2485 - val_accuracy: 0.9083
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1523 - accuracy: 0.9434 - val_loss: 0.2421 - val_accuracy: 0.9140
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1335 - accuracy: 0.9505 - val_loss: 0.2529 - val_accuracy: 0.9125
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1129 - accuracy: 0.9573 - val_loss: 0.2901 - val_accuracy: 0.9123
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0985 - accuracy: 0.9625 - val_loss: 0.2789 - val_accuracy: 0.9204
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0854 - accuracy: 0.9673 - val_loss: 0.3171 - val_accuracy: 0.9169
# CPU times: user 1min 36s, sys: 8.1 s, total: 1min 44s
# Wall time: 2min 23s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1152)              0
#
#  dense_6 (Dense)             (None, 128)               147584
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_4)

# %%
model_5 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

model_5.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_5.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.4364 - accuracy: 0.8403 - val_loss: 0.3453 - val_accuracy: 0.8738
# Epoch 2/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2789 - accuracy: 0.8979 - val_loss: 0.2734 - val_accuracy: 0.8983
# Epoch 3/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2292 - accuracy: 0.9157 - val_loss: 0.2500 - val_accuracy: 0.9063
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1990 - accuracy: 0.9274 - val_loss: 0.2466 - val_accuracy: 0.9114
# Epoch 5/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1722 - accuracy: 0.9362 - val_loss: 0.2278 - val_accuracy: 0.9195
# Epoch 6/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1513 - accuracy: 0.9434 - val_loss: 0.2623 - val_accuracy: 0.9115
# Epoch 7/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1323 - accuracy: 0.9499 - val_loss: 0.2412 - val_accuracy: 0.9161
# Epoch 8/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1142 - accuracy: 0.9575 - val_loss: 0.2724 - val_accuracy: 0.9124
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1005 - accuracy: 0.9624 - val_loss: 0.2529 - val_accuracy: 0.9235
# Epoch 10/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0876 - accuracy: 0.9668 - val_loss: 0.3010 - val_accuracy: 0.9144
# CPU times: user 1min 47s, sys: 8.39 s, total: 1min 56s
# Wall time: 2min 4s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_5.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 64)        18496
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 128)         73856
#
#  max_pooling2d_11 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 1152)              0
#
#  dense_10 (Dense)            (None, 128)               147584
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 241546 (943.54 KB)
# Trainable params: 241546 (943.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_5)

# %% [markdown]
# # 1

# %%
model_6 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(256, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

model_6.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_6.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 21s 10ms/step - loss: 0.4533 - accuracy: 0.8329 - val_loss: 0.3181 - val_accuracy: 0.8852
# Epoch 2/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2786 - accuracy: 0.8978 - val_loss: 0.2933 - val_accuracy: 0.8906
# Epoch 3/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2326 - accuracy: 0.9135 - val_loss: 0.2573 - val_accuracy: 0.9069
# Epoch 4/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.2010 - accuracy: 0.9253 - val_loss: 0.2427 - val_accuracy: 0.9112
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1785 - accuracy: 0.9333 - val_loss: 0.2594 - val_accuracy: 0.9115
# Epoch 6/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1561 - accuracy: 0.9414 - val_loss: 0.2696 - val_accuracy: 0.9075
# Epoch 7/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1380 - accuracy: 0.9481 - val_loss: 0.2685 - val_accuracy: 0.9089
# Epoch 8/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1200 - accuracy: 0.9554 - val_loss: 0.2891 - val_accuracy: 0.9116
# Epoch 9/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1043 - accuracy: 0.9605 - val_loss: 0.2873 - val_accuracy: 0.9089
# Epoch 10/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0936 - accuracy: 0.9645 - val_loss: 0.2962 - val_accuracy: 0.9152
# CPU times: user 2min, sys: 8.57 s, total: 2min 9s
# Wall time: 2min 23s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_6.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_12 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 64)        18496
#
#  max_pooling2d_13 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 128)         73856
#
#  max_pooling2d_14 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  conv2d_15 (Conv2D)          (None, 3, 3, 256)         295168
#
#  max_pooling2d_15 (MaxPooli  (None, 1, 1, 256)         0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 128)               32896
#
#  dense_13 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 422026 (1.61 MB)
# Trainable params: 422026 (1.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_6)

# %% [markdown]
# # 2

# %%
model_7 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (6,6), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (6,6), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (6,6), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

model_7.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_7.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.4229 - accuracy: 0.8449 - val_loss: 0.3234 - val_accuracy: 0.8811
# Epoch 2/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2716 - accuracy: 0.9000 - val_loss: 0.2773 - val_accuracy: 0.8958
# Epoch 3/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2266 - accuracy: 0.9148 - val_loss: 0.2561 - val_accuracy: 0.9056
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1942 - accuracy: 0.9274 - val_loss: 0.2626 - val_accuracy: 0.9078
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1672 - accuracy: 0.9370 - val_loss: 0.2622 - val_accuracy: 0.9074
# Epoch 6/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1438 - accuracy: 0.9459 - val_loss: 0.2707 - val_accuracy: 0.9161
# Epoch 7/10
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.1248 - accuracy: 0.9525 - val_loss: 0.2941 - val_accuracy: 0.9138
# Epoch 8/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1072 - accuracy: 0.9589 - val_loss: 0.3222 - val_accuracy: 0.9106
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0992 - accuracy: 0.9615 - val_loss: 0.3200 - val_accuracy: 0.9092
# Epoch 10/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0844 - accuracy: 0.9675 - val_loss: 0.3400 - val_accuracy: 0.9138
# CPU times: user 1min 52s, sys: 8.51 s, total: 2min
# Wall time: 2min 23s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_7.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_31 (Conv2D)          (None, 28, 28, 32)        1184
#
#  max_pooling2d_31 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 64)        73792
#
#  max_pooling2d_32 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 128)         295040
#
#  max_pooling2d_33 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  flatten_12 (Flatten)        (None, 1152)              0
#
#  dense_24 (Dense)            (None, 128)               147584
#
#  dense_25 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 518890 (1.98 MB)
# Trainable params: 518890 (1.98 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_7)

# %% [markdown]
# # 3

# %%
model_8 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (6,6), activation = 'relu' ),
      MaxPooling2D( (4,4), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (6,6), activation = 'relu' ),
      MaxPooling2D( (4,4), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (6,6), activation = 'relu' ),
      MaxPooling2D( (4,4), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

model_8.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_8.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.4430 - accuracy: 0.8372 - val_loss: 0.3508 - val_accuracy: 0.8716
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2894 - accuracy: 0.8918 - val_loss: 0.3038 - val_accuracy: 0.8897
# Epoch 3/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.2504 - accuracy: 0.9075 - val_loss: 0.2748 - val_accuracy: 0.8997
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2254 - accuracy: 0.9155 - val_loss: 0.2835 - val_accuracy: 0.8932
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2058 - accuracy: 0.9238 - val_loss: 0.2570 - val_accuracy: 0.8998
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1908 - accuracy: 0.9289 - val_loss: 0.2515 - val_accuracy: 0.9092
# Epoch 7/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1744 - accuracy: 0.9334 - val_loss: 0.2437 - val_accuracy: 0.9140
# Epoch 8/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1609 - accuracy: 0.9390 - val_loss: 0.2588 - val_accuracy: 0.9171
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1496 - accuracy: 0.9440 - val_loss: 0.2705 - val_accuracy: 0.9123
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1396 - accuracy: 0.9471 - val_loss: 0.2754 - val_accuracy: 0.9166
# CPU times: user 1min 42s, sys: 8.69 s, total: 1min 51s
# Wall time: 1min 44s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_8.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 28, 28, 32)        1184
#
#  max_pooling2d_34 (MaxPooli  (None, 13, 13, 32)        0
#  ng2D)
#
#  conv2d_35 (Conv2D)          (None, 13, 13, 64)        73792
#
#  max_pooling2d_35 (MaxPooli  (None, 5, 5, 64)          0
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 5, 5, 128)         295040
#
#  max_pooling2d_36 (MaxPooli  (None, 1, 1, 128)         0
#  ng2D)
#
#  flatten_13 (Flatten)        (None, 128)               0
#
#  dense_26 (Dense)            (None, 128)               16512
#
#  dense_27 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 387818 (1.48 MB)
# Trainable params: 387818 (1.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_8)

# %% [markdown]
# # 4

# %%
model_9 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (6,6), activation = 'softmax' ),
      MaxPooling2D( (4,4), strides = 2),
      Conv2D(64, padding = 'same', kernel_size = (6,6), activation = 'softmax' ),
      MaxPooling2D( (4,4), strides = 2),
      Conv2D(128, padding = 'same', kernel_size = (6,6), activation = 'softmax' ),
      MaxPooling2D( (4,4), strides = 2),
      Flatten(), # перевод в одномерный массив
      Dense(128,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

model_9.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_9.fit(x_train, y_train_cat, batch_size=32, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 6ms/step - loss: 2.3028 - accuracy: 0.0967 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.3028 - accuracy: 0.0979 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.3028 - accuracy: 0.0980 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 2.3028 - accuracy: 0.0984 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 5/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 2.3028 - accuracy: 0.0993 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 2.3028 - accuracy: 0.0970 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 2.3028 - accuracy: 0.0984 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 2.3028 - accuracy: 0.0993 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.3028 - accuracy: 0.0982 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.3028 - accuracy: 0.0994 - val_loss: 2.3026 - val_accuracy: 0.1000
# CPU times: user 1min 46s, sys: 8.4 s, total: 1min 54s
# Wall time: 1min 47s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_9.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_37 (Conv2D)          (None, 28, 28, 32)        1184
#
#  max_pooling2d_37 (MaxPooli  (None, 13, 13, 32)        0
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 13, 13, 64)        73792
#
#  max_pooling2d_38 (MaxPooli  (None, 5, 5, 64)          0
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, 5, 5, 128)         295040
#
#  max_pooling2d_39 (MaxPooli  (None, 1, 1, 128)         0
#  ng2D)
#
#  flatten_14 (Flatten)        (None, 128)               0
#
#  dense_28 (Dense)            (None, 128)               16512
#
#  dense_29 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 387818 (1.48 MB)
# Trainable params: 387818 (1.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_9)

# %% [markdown]
# # 5

# %%
model_10 = keras.Sequential([
      keras.Input(shape=input_shape),
      Conv2D(32, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 4),
      Conv2D(64, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 4),
      Conv2D(128, padding = 'same', kernel_size = (3,3), activation = 'relu' ),
      MaxPooling2D( (2,2), strides = 4),
      Flatten(), # перевод в одномерный массив
      Dense(32,activation = 'relu'), # количество входных нейронов
      Dense(10, activation = 'softmax')   # количество выходных нейронов
      ] )

model_10.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# %%time

history = model_10.fit(x_train, y_train_cat, batch_size=64, epochs=10,validation_data =(x_test, y_test_cat) )
# Out:
# Epoch 1/10
# 938/938 [==============================] - 8s 6ms/step - loss: 0.6114 - accuracy: 0.7798 - val_loss: 0.4592 - val_accuracy: 0.8282
# Epoch 2/10
# 938/938 [==============================] - 5s 5ms/step - loss: 0.3817 - accuracy: 0.8598 - val_loss: 0.3904 - val_accuracy: 0.8548
# Epoch 3/10
# 938/938 [==============================] - 5s 6ms/step - loss: 0.3324 - accuracy: 0.8773 - val_loss: 0.3414 - val_accuracy: 0.8718
# Epoch 4/10
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2976 - accuracy: 0.8896 - val_loss: 0.3218 - val_accuracy: 0.8848
# Epoch 5/10
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2752 - accuracy: 0.8980 - val_loss: 0.3394 - val_accuracy: 0.8738
# Epoch 6/10
# 938/938 [==============================] - 5s 6ms/step - loss: 0.2603 - accuracy: 0.9026 - val_loss: 0.3041 - val_accuracy: 0.8868
# Epoch 7/10
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2428 - accuracy: 0.9105 - val_loss: 0.2917 - val_accuracy: 0.8931
# Epoch 8/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2280 - accuracy: 0.9155 - val_loss: 0.2974 - val_accuracy: 0.8940
# Epoch 9/10
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2148 - accuracy: 0.9192 - val_loss: 0.2735 - val_accuracy: 0.8970
# Epoch 10/10
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2025 - accuracy: 0.9251 - val_loss: 0.2877 - val_accuracy: 0.8941
# CPU times: user 54.7 s, sys: 5.01 s, total: 59.7 s
# Wall time: 1min 23s

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_10.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_40 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_41 (Conv2D)          (None, 7, 7, 64)          18496
#
#  max_pooling2d_41 (MaxPooli  (None, 2, 2, 64)          0
#  ng2D)
#
#  conv2d_42 (Conv2D)          (None, 2, 2, 128)         73856
#
#  max_pooling2d_42 (MaxPooli  (None, 1, 1, 128)         0
#  ng2D)
#
#  flatten_15 (Flatten)        (None, 128)               0
#
#  dense_30 (Dense)            (None, 32)                4128
#
#  dense_31 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 97130 (379.41 KB)
# Trainable params: 97130 (379.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(model_10)
